# %%
tp=90
fn=210
fp=140
tn=9560

# %%
precision=tp/(tp+fp)
precision
# Out:
# 0.391304347826087

# %%
accuracy=(tp+tn)/(tp+tn+fp+fn)
accuracy
# Out:
# 0.965

# %%
recall=tp/(tp+fn)
recall
# Out:
# 0.3

# %%
error=(fp+fn)/(tp+tn+fn+fp)
error
# Out:
# 0.035
