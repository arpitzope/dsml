# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("cosmetics.csv") #importing the cosmetics.csv file
data.head()
# Out:
#      Age  Income  Gender       Ms Buys
# 0    <21    High    Male   Single   No
# 1    <21    High    Male  Married   No
# 2  21-35    High    Male   Single  Yes
# 3    >35  Medium    Male   Single  Yes
# 4    >35     Low  Female   Single  Yes

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %%
data['Buys'].value_counts()
# Out:
# Yes    9
# No     5
# Name: Buys, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
#data=data.apply(le.fit_transform)
x=data.iloc[:,:-1] #-1 means don't take last column 
x=x.apply(le.fit_transform)
#find label with their encoded value
# list( zip(data.iloc[:,0], x.iloc[:,0]))
list( zip(data.iloc[:,1], x.iloc[:,1]))
# list( zip(data.iloc[:,2], x.iloc[:,2]))
# list( zip(data.iloc[:,3], x.iloc[:,3]))
# Out:
# [('High', 0),
#  ('High', 0),
#  ('High', 0),
#  ('Medium', 2),
#  ('Low', 1),
#  ('Low', 1),
#  ('Low', 1),
#  ('Medium', 2),
#  ('Low', 1),
#  ('Medium', 2),
#  ('Medium', 2),
#  ('Medium', 2),
#  ('High', 0),
#  ('Medium', 2)]

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
y=data.iloc[:,-1]

# %%
from sklearn.tree import DecisionTreeClassifier
classifier=DecisionTreeClassifier(criterion='entropy')
classifier.fit(x,y)

# %%
test_x=np.array([1,1,0,0])
pred_y=classifier.predict([test_x])
print("Predicted class for input [Age < 21, Income = Low,Gender = Female, Marital Status = Married]\n", test_x," is ",pred_y[0])
# Out:
# Predicted class for input [Age < 21, Income = Low,Gender = Female, Marital Status = Married]
#  [1 1 0 0]  is  Yes
# c:\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
