# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("Dataset/house_price_prediction.csv")

# %%
#print variance
data.var()
# Out:
# C:\Users\PRATIK RATHOD\AppData\Local\Temp\ipykernel_5744\3354808303.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.var()
# price            3.179096e+11
# bedrooms         8.260049e-01
# bathrooms        6.143128e-01
# sqft_living      9.277676e+05
# sqft_lot         1.287693e+09
# floors           2.897544e-01
# waterfront       7.123997e-03
# view             6.059139e-01
# condition        4.586402e-01
# sqft_above       7.433353e+05
# sqft_basement    2.154234e+05
# yr_built         8.839828e+02
# yr_renovated     9.592528e+05
# dtype: float64

# %% [raw]
# #print standard deviation
# data.std()

# %%
np.std(data,axis=0) #calculate standrad deviation for each column
# Out:
# price            563773.412835
# bedrooms              0.908749
# bathrooms             0.783696
# sqft_living         963.102214
# sqft_lot          35880.535451
# floors                0.538230
# waterfront            0.084395
# view                  0.778320
# condition             0.677156
# sqft_above          862.075258
# sqft_basement       464.086776
# yr_built             29.728616
# yr_renovated        979.308073
# dtype: float64

# %%
np.std(data,axis=1) #calculate standrad deviation for each row
# Out:
# 0        83107.658862
# 1       634861.806312
# 2        90791.743891
# 3       111626.159817
# 4       146175.650503
#             ...
# 4595     81838.969457
# 4596    142075.672003
# 4597    110776.128289
# 4598     53944.839537
# 4599     58531.903880
# Length: 4600, dtype: float64

# %%
#percentile
data.price.quantile(0.1)
# Out:
# 239950.0
